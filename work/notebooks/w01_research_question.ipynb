# %% [markdown]
# <a href="https://colab.research.google.com/github/thehmfpk/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My lane
#
# I choose the Content Refresh Prioritization lane.
#
# I selected this lane because it represents a practical machine learning engineering problem: building a system that helps prioritize which content pages should be reviewed first based on historical performance data.
#
# The goal is not to automatically decide what changes should be made, but to create a data-driven ranking system that helps teams focus their effort on pages where improvement opportunities may exist.
#
# This lane allows me to work on important ML engineering concepts including feature engineering, ranking, model evaluation, and decision-support systems.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The question: decision, action, cost of a wrong call
#
# ### Research Question
#
# Which pages should be prioritized for content refresh review based on signals from their historical search performance?
#
# ### Decision
#
# The decision is which pages a content team should review first instead of manually checking thousands of pages.
#
# ### Who acts and what they do
#
# A content or SEO team acts on the output by reviewing high-priority pages and deciding whether updates, improvements, or further investigation are needed.
#
# ### Cost of a wrong recommendation
#
# A wrong recommendation can waste team time by reviewing pages that do not need attention. It can also cause important declining pages to be missed if the ranking system fails to identify them.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/thehmfpk/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
# !git clone https://github.com/thehmfpk/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
import os

os.chdir("flyrank-ml-internship")

print(os.getcwd())
# Out:
# /flyrank-ml-internship

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))

print("\nTrend distribution:")
print(df["trend_direction"].value_counts())

print("\nAverage impressions in 90 days:", round(df["impressions_90d"].mean(), 2))

print("\nAverage CTR:", round(df["ctr"].mean(), 4))
# Out:
# Total pages: 30000
#
# Trend distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average impressions in 90 days: 5200.37
#
# Average CTR: 0.5107

# %% [markdown]
# ## Data Observations
#
# The starter dataset contains 30,000 content pages with different search performance patterns.
#
# The dataset contains multiple trend directions, including declining and growing pages, which shows that pages do not perform the same over time.
#
# The variation in impressions_90d and CTR indicates that there are measurable signals that can help prioritize pages for further review using a data-driven approach.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful words: what I can and can't claim
#
# This project can identify observed patterns in content performance and provide decision-support by ranking pages that may need review.
#
# I can evaluate whether ML models can prioritize pages better than simple rules using available historical data.
#
# I cannot claim that the model understands Google's ranking algorithm, causes traffic changes, or guarantees that updating a page will improve performance.
#
# The results should be considered directional recommendations that support human decision-making.

# %% [markdown]
# ## Self-check
#
# ✓ My lane is clearly defined.
#
# ✓ My work improves a specific decision: which pages should be reviewed first.
#
# ✓ A person can act on the output.
#
# ✓ I explained the cost of wrong recommendations.
#
# ✓ I used real observations from the starter dataset.
#
# ✓ My claims are decision-support, not causal claims.
#
# ✓ My notebook runs from start to finish without errors.
